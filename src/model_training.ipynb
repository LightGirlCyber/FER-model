# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.regularizers import l2
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.metrics import Precision, Recall
from focal_loss import BinaryFocalLoss
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
from datetime import datetime
import os
import numpy as np
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm  
import cv2
from sklearn.preprocessing import LabelEncoder

# %%
# Set all random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %%
num_class=9
img_rows,img_cols=48,48 #image size
batch_size=16 #decrease from 32 to 16 back to 32

# %%
# For GPU determinism (if using GPU)
tf.config.experimental.enable_op_determinism()

# %%
# Regularization strength (tunable)
kernel_regularizer = l1_l2(l1=1e-5, l2=1e-4) #new, l1_l2 regularisation

# %%
train_data=r"C:\Users\nourm\OneDrive\Desktop\PROJECTS\UNITY MODEL PROJECT\FER-2013\train"

validation_data=r"C:\Users\nourm\OneDrive\Desktop\PROJECTS\UNITY MODEL PROJECT\FER-2013\test"

# %%
# Get the list of folders in the directory as classes
classes=os.listdir(train_data+'/')
classes
# Out:
# ['angry',
#  'disgust',
#  'fear',
#  'happy',
#  'kissing',
#  'neutral',
#  'sad',
#  'sleepy',
#  'surprise']

# %%
def get_class_distribution(dataset_path):
    class_counts = {folder: len(os.listdir(os.path.join(dataset_path, folder)))
                    for folder in os.listdir(dataset_path)
                    if os.path.isdir(os.path.join(dataset_path, folder))}
    return class_counts

# %%
def plot_class_distribution(class_counts, title="Class Distribution"):
    df = pd.DataFrame(list(class_counts.items()), columns=['Emotion', 'Count'])
    plt.figure(figsize=(10, 6))
    sns.barplot(x='Emotion', y='Count', data=df)
    plt.title(title)
    plt.xlabel('Emotion Class')
    plt.ylabel('Number of Images')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
original_counts = get_class_distribution(train_data)
plot_class_distribution(original_counts, title="Original Class Distribution (Before Oversampling)")

# %%
OVERSAMPLED_TRAIN_PATH = r"C:\Users\nourm\OneDrive\Desktop\PROJECTS\UNITY MODEL PROJECT\FER-2013\oversampled_train"
TARGET_LENGTH = 8000  # Set to max class size or any desired balance

def oversample_dataset(train_dir=train_data, oversampled_dir=OVERSAMPLED_TRAIN_PATH, target_length=TARGET_LENGTH):
    if not os.path.exists(oversampled_dir):
        os.makedirs(oversampled_dir)

    for class_name in os.listdir(train_dir):
        class_path = os.path.join(train_dir, class_name)
        if not os.path.isdir(class_path):
            continue

        images = os.listdir(class_path)
        num_images = len(images)
        num_duplicates = target_length // num_images
        remainder = target_length % num_images

        dest_dir = os.path.join(oversampled_dir, class_name)
        os.makedirs(dest_dir, exist_ok=True)

        # Duplicate all images num_duplicates times
        for i in range(num_duplicates):
            for image_name in images:
                src_path = os.path.join(class_path, image_name)
                dst_path = os.path.join(dest_dir, f"{i}_{image_name}")
                Image.open(src_path).save(dst_path)

        # Add remainder images
        for i, image_name in enumerate(images[:remainder]):
            src_path = os.path.join(class_path, image_name)
            dst_path = os.path.join(dest_dir, f"{num_duplicates}_{i}_{image_name}")
            Image.open(src_path).save(dst_path)

#oversample_dataset()

# %%
# def smote_augment_multi_folder(input_folder, output_folder, num_augmented_images=1000):
   

#     datagen = ImageDataGenerator(
#         rotation_range=20,
#         width_shift_range=0.1,
#         height_shift_range=0.1,
#         shear_range=0.15,
#         zoom_range=0.1,
#         horizontal_flip=True,
#         fill_mode='nearest'
#     )

#     if not os.path.exists(input_folder):
#         print(f"[ERROR] Input folder does not exist: {input_folder}")
#         return

#     os.makedirs(output_folder, exist_ok=True)

#     for subfolder in os.listdir(input_folder):
#         input_subfolder_path = os.path.join(input_folder, subfolder)
#         output_subfolder_path = os.path.join(output_folder, subfolder)

#         if not os.path.isdir(input_subfolder_path):
#             continue

#         os.makedirs(output_subfolder_path, exist_ok=True)

#         image_files = [f for f in os.listdir(input_subfolder_path)
#                        if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

#         if not image_files:
#             print(f"[WARNING] No images in: {input_subfolder_path}")
#             continue

#         print(f"[INFO] Processing '{subfolder}' - {len(image_files)} images found")

#         count = 0
#         while count < num_augmented_images:
#             img_file = random.choice(image_files)
#             img_path = os.path.join(input_subfolder_path, img_file)

#             try:
#                 img = load_img(img_path)
#                 x = img_to_array(img)
#                 x = x.reshape((1,) + x.shape)

#                 # Generate a batch of 1 augmented image
#                 for batch in datagen.flow(x, batch_size=1):
#                     aug_img = array_to_img(batch[0])

#                     # Generate a unique filename
#                     timestamp = datetime.now().strftime('%Y%m%d%H%M%S%f')
#                     save_name = f"aug_{count}_{timestamp}.png"
#                     save_path = os.path.join(output_subfolder_path, save_name)

#                     aug_img.save(save_path)
#                     count += 1
#                     break

#             except Exception as e:
#                 print(f"[ERROR] Skipping file '{img_file}': {e}")
#                 continue

#         print(f"[DONE] Generated {count} images for '{subfolder}'")

#     print(f"\n[COMPLETE] All folders processed. Output saved to: {output_folder}")

# %%
# SMOTED_OVERSAMPLED_TRAIN_PATH=r"C:\Users\nourm\OneDrive\Desktop\PROJECTS\UNITY MODEL PROJECT\FER-2013 (USED)\SMOTED_OVERSAMPLED"

# smote_augment_multi_folder(
#     input_folder=train_data,
#     output_folder=SMOTED_OVERSAMPLED_TRAIN_PATH,
#     num_augmented_images=7215
# )

# %%
#SMOTED_OVERSAMPLED_TEST=R"C:\Users\nourm\OneDrive\Desktop\PROJECTS\UNITY MODEL PROJECT\FER-2013 (USED)\SMOTED_OVERSAMPLED_TEST"

# smote_augment_multi_folder(
#     input_folder=validation_data,
#     output_folder=SMOTED_OVERSAMPLED_TEST,
#     num_augmented_images=1774
# )

# %%
original_counts = get_class_distribution(OVERSAMPLED_TRAIN_PATH)
plot_class_distribution(original_counts, title="oversampled smote Class Distribution ")

# %%
#image data generator section

#here we generated some images 

train_dataGen=ImageDataGenerator(
    rescale=1./255,
    fill_mode='nearest',
    rotation_range=15,           # Increase from 10 to 15
    shear_range=0.10,            # Increase from 0.1 to 0.2 back to 0.15
    zoom_range=0.10,             # Increase from 0.1 to 0.2 back to 0.15 back to 0.1
    width_shift_range=0.10,      # Increase from 0.1 to 0.2 back to 0.15
    height_shift_range=0.10,     # Increase from 0.1 to 0.2 back to 0.15
    horizontal_flip=True
    #brightness_range=[0.8, 1.2], # ADD: brightness variation- remove for now
    #channel_shift_range=0.1      # ADD: slight channel shift remove for now 
)


validation_dataGen=ImageDataGenerator(rescale=1./255)

#give to model to train-train parameters

train_generator = train_dataGen.flow_from_directory(
  OVERSAMPLED_TRAIN_PATH,
  color_mode='grayscale',
  target_size=(img_rows,img_cols) , 
  batch_size=batch_size,
  class_mode='categorical', 
  shuffle=True
   )

#new - add class weighs

from sklearn.utils.class_weight import compute_class_weight

labels = train_generator.classes  # Numpy array of class indices
class_weights = compute_class_weight(class_weight='balanced',
                                     classes=np.unique(labels),
                                     y=labels)
class_weights_dict = dict(enumerate(class_weights))
print("Class weights:", class_weights_dict)

#end of new

#validation parameters
validation_generator = validation_dataGen.flow_from_directory(validation_data,
color_mode='grayscale',
 target_size=(img_rows,img_cols) , 
 batch_size=batch_size,
   class_mode='categorical', 
   shuffle=True
   )
# Out:
# Found 72000 images belonging to 9 classes.
# Class weights: {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0, 4: 1.0, 5: 1.0, 6: 1.0, 7: 1.0, 8: 1.0}
# Found 7628 images belonging to 9 classes.

# %%
model= Sequential()

#change, block 1-4, increase dropout from 0.2 to 0.3 0.2
#change, block 5-6, decrease dropout from 0.5 to 0.4 0.3


# Block 1 - Deeper feature extraction
model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001), input_shape=(img_rows, img_cols, 1)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))


# Block 2 - Increased capacity
model.add(Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))


# Block 3 - Higher-level features
model.add(Conv2D(128, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(128, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(128, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))


# Block 4 - Complex pattern recognition
model.add(Conv2D(256, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(256, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(256, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))


# Block 5 - Additional deep features
model.add(Conv2D(512, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(512, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Dropout(0.4))


# Global Average Pooling - reduces overfitting compared to Flatten
model.add(GlobalAveragePooling2D())


# Fully Connected Dense Layers
model.add(Dense(256, kernel_initializer='he_normal', kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(128, kernel_initializer='he_normal', kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())
model.add(Dropout(0.5))


# Output Layer
model.add(Dense(num_class, kernel_initializer='he_normal'))
model.add(Activation('softmax'))


print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 48, 48, 32)        320
#
#  activation_17 (Activation)  (None, 48, 48, 32)        0
#
#  batch_normalization_16 (Bat  (None, 48, 48, 32)       128
#  chNormalization)
#
#  conv2d_15 (Conv2D)          (None, 48, 48, 32)        9248
#
#  activation_18 (Activation)  (None, 48, 48, 32)        0
#
#  batch_normalization_17 (Bat  (None, 48, 48, 32)       128
#  chNormalization)
#
#  conv2d_16 (Conv2D)          (None, 48, 48, 32)        9248
#
#  activation_19 (Activation)  (None, 48, 48, 32)        0
#
#  batch_normalization_18 (Bat  (None, 48, 48, 32)       128
#  chNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 24, 24, 32)       0
#  2D)
#
#  dropout_7 (Dropout)         (None, 24, 24, 32)        0
#
#  conv2d_17 (Conv2D)          (None, 24, 24, 64)        18496
#
#  activation_20 (Activation)  (None, 24, 24, 64)        0
#
#  batch_normalization_19 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  conv2d_18 (Conv2D)          (None, 24, 24, 64)        36928
#
#  activation_21 (Activation)  (None, 24, 24, 64)        0
#
#  batch_normalization_20 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  conv2d_19 (Conv2D)          (None, 24, 24, 64)        36928
#
#  activation_22 (Activation)  (None, 24, 24, 64)        0
#
#  batch_normalization_21 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_8 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_20 (Conv2D)          (None, 12, 12, 128)       73856
#
#  activation_23 (Activation)  (None, 12, 12, 128)       0
#
#  batch_normalization_22 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  conv2d_21 (Conv2D)          (None, 12, 12, 128)       147584
#
#  activation_24 (Activation)  (None, 12, 12, 128)       0
#
#  batch_normalization_23 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  conv2d_22 (Conv2D)          (None, 12, 12, 128)       147584
#
#  activation_25 (Activation)  (None, 12, 12, 128)       0
#
#  batch_normalization_24 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_9 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_23 (Conv2D)          (None, 6, 6, 256)         295168
#
#  activation_26 (Activation)  (None, 6, 6, 256)         0
#
#  batch_normalization_25 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv2d_24 (Conv2D)          (None, 6, 6, 256)         590080
#
#  activation_27 (Activation)  (None, 6, 6, 256)         0
#
#  batch_normalization_26 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv2d_25 (Conv2D)          (None, 6, 6, 256)         590080
#
#  activation_28 (Activation)  (None, 6, 6, 256)         0
#
#  batch_normalization_27 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  dropout_10 (Dropout)        (None, 3, 3, 256)         0
#
#  conv2d_26 (Conv2D)          (None, 3, 3, 512)         1180160
#
#  activation_29 (Activation)  (None, 3, 3, 512)         0
#
#  batch_normalization_28 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv2d_27 (Conv2D)          (None, 3, 3, 512)         2359808
#
#  activation_30 (Activation)  (None, 3, 3, 512)         0
#
#  batch_normalization_29 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 3, 3, 512)         0
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  activation_31 (Activation)  (None, 256)               0
#
#  batch_normalization_30 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_12 (Dropout)        (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  activation_32 (Activation)  (None, 128)               0
#
#  batch_normalization_31 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_5 (Dense)             (None, 9)                 1161
#
#  activation_33 (Activation)  (None, 9)                 0
#
# =================================================================
# Total params: 5,672,265
# Trainable params: 5,666,569
# Non-trainable params: 5,696
# _________________________________________________________________
# None

# %%
from keras.optimizers import RMSprop,SGD,Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint = ModelCheckpoint(r'C:\Users\nourm\OneDrive\Desktop\PROJECTS\UNITY MODEL PROJECT\Emotion_little_vgg.h5',
                            monitor='val_loss',
                            mode='min',
                            save_best_only=True,
                            verbose=1)

earlystop = EarlyStopping(monitor='val_loss',
                         min_delta=0,
                         patience=7, #increase from 3
                         verbose=1,
                         restore_best_weights=True
                         )

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                            factor=0.5, #change from 0.2
                            patience=5, #increase from 3
                            verbose=1,
                            min_delta=0.0001)

callbacks = [earlystop,reduce_lr]

optimizer = Adam(learning_rate=0.0001 , clipnorm=1.0)  # Reduced from 0.001

# %%
from tensorflow.keras import backend as K  

def f1_score(y_true, y_pred):
    """Custom F1 score metric"""
    def recall_fn(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision_fn(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    precision_val = precision_fn(y_true, y_pred)
    recall_val = recall_fn(y_true, y_pred)
    return 2*((precision_val*recall_val)/(precision_val+recall_val+K.epsilon()))

# %%
from tensorflow.keras.metrics import Precision, Recall

model.compile(optimizer=optimizer, 
              loss='categorical_crossentropy', 
              metrics=['accuracy', Precision(), Recall(),f1_score]
              )

nb_train_samples = train_generator.samples
nb_validation_samples = validation_generator.samples
epochs=60 #how many times to train same image, model will go 25 times in every folder #increase from 25


history=model.fit(
                train_generator,
                steps_per_epoch=nb_train_samples//batch_size,
                epochs=epochs,
                callbacks=callbacks,
                validation_data=validation_generator,
                validation_steps=nb_validation_samples//batch_size,
                 class_weight=class_weights_dict )

model.save('FER_model.h5')
# Out:
# Epoch 1/60
# 4500/4500 [==============================] - 706s 156ms/step - loss: 2.9108 - accuracy: 0.2228 - precision_1: 0.3472 - recall_1: 0.1096 - f1_score: 0.1655 - val_loss: 2.6363 - val_accuracy: 0.2419 - val_precision_1: 0.4058 - val_recall_1: 0.0750 - val_f1_score: 0.1228 - lr: 1.0000e-04
# Epoch 2/60
# 4500/4500 [==============================] - 457s 102ms/step - loss: 2.2653 - accuracy: 0.3730 - precision_1: 0.6608 - recall_1: 0.2076 - f1_score: 0.3111 - val_loss: 2.2330 - val_accuracy: 0.3728 - val_precision_1: 0.5526 - val_recall_1: 0.1925 - val_f1_score: 0.2797 - lr: 1.0000e-04
# Epoch 3/60
# 4500/4500 [==============================] - 265s 59ms/step - loss: 1.9253 - accuracy: 0.4800 - precision_1: 0.7543 - recall_1: 0.3033 - f1_score: 0.4278 - val_loss: 1.9800 - val_accuracy: 0.4550 - val_precision_1: 0.6420 - val_recall_1: 0.2965 - val_f1_score: 0.3986 - lr: 1.0000e-04
# Epoch 4/60
# 4500/4500 [==============================] - 317s 70ms/step - loss: 1.7096 - accuracy: 0.5418 - precision_1: 0.7885 - recall_1: 0.3723 - f1_score: 0.5012 - val_loss: 1.8013 - val_accuracy: 0.5013 - val_precision_1: 0.6601 - val_recall_1: 0.3498 - val_f1_score: 0.4516 - lr: 1.0000e-04
# Epoch 5/60
# 4500/4500 [==============================] - 395s 88ms/step - loss: 1.5668 - accuracy: 0.5821 - precision_1: 0.8031 - recall_1: 0.4168 - f1_score: 0.5444 - val_loss: 1.7354 - val_accuracy: 0.5214 - val_precision_1: 0.6702 - val_recall_1: 0.3771 - val_f1_score: 0.4773 - lr: 1.0000e-04
# Epoch 6/60
# 4500/4500 [==============================] - 352s 78ms/step - loss: 1.4606 - accuracy: 0.6094 - precision_1: 0.8110 - recall_1: 0.4510 - f1_score: 0.5755 - val_loss: 1.6394 - val_accuracy: 0.5463 - val_precision_1: 0.6913 - val_recall_1: 0.3922 - val_f1_score: 0.4943 - lr: 1.0000e-04
# Epoch 7/60
# 4500/4500 [==============================] - 360s 80ms/step - loss: 1.3842 - accuracy: 0.6293 - precision_1: 0.8186 - recall_1: 0.4796 - f1_score: 0.6008 - val_loss: 1.5786 - val_accuracy: 0.5534 - val_precision_1: 0.7021 - val_recall_1: 0.4066 - val_f1_score: 0.5086 - lr: 1.0000e-04
# Epoch 8/60
# 4500/4500 [==============================] - 358s 80ms/step - loss: 1.3182 - accuracy: 0.6460 - precision_1: 0.8225 - recall_1: 0.5032 - f1_score: 0.6205 - val_loss: 1.6082 - val_accuracy: 0.5565 - val_precision_1: 0.6786 - val_recall_1: 0.4270 - val_f1_score: 0.5194 - lr: 1.0000e-04
# Epoch 9/60
# 4500/4500 [==============================] - 360s 80ms/step - loss: 1.2659 - accuracy: 0.6593 - precision_1: 0.8234 - recall_1: 0.5256 - f1_score: 0.6377 - val_loss: 1.5785 - val_accuracy: 0.5695 - val_precision_1: 0.6896 - val_recall_1: 0.4334 - val_f1_score: 0.5278 - lr: 1.0000e-04
# Epoch 10/60
# 4500/4500 [==============================] - 364s 81ms/step - loss: 1.2180 - accuracy: 0.6727 - precision_1: 0.8281 - recall_1: 0.5425 - f1_score: 0.6521 - val_loss: 1.5730 - val_accuracy: 0.5739 - val_precision_1: 0.6892 - val_recall_1: 0.4592 - val_f1_score: 0.5473 - lr: 1.0000e-04
# Epoch 11/60
# 4500/4500 [==============================] - 363s 81ms/step - loss: 1.1798 - accuracy: 0.6843 - precision_1: 0.8313 - recall_1: 0.5583 - f1_score: 0.6644 - val_loss: 1.5511 - val_accuracy: 0.5720 - val_precision_1: 0.6899 - val_recall_1: 0.4539 - val_f1_score: 0.5431 - lr: 1.0000e-04
# Epoch 12/60
# 4500/4500 [==============================] - 384s 85ms/step - loss: 1.1514 - accuracy: 0.6933 - precision_1: 0.8320 - recall_1: 0.5705 - f1_score: 0.6733 - val_loss: 1.4697 - val_accuracy: 0.5948 - val_precision_1: 0.7165 - val_recall_1: 0.4655 - val_f1_score: 0.5592 - lr: 1.0000e-04
# Epoch 13/60
# 4500/4500 [==============================] - 385s 86ms/step - loss: 1.1233 - accuracy: 0.6988 - precision_1: 0.8351 - recall_1: 0.5840 - f1_score: 0.6840 - val_loss: 1.4636 - val_accuracy: 0.5943 - val_precision_1: 0.7042 - val_recall_1: 0.4823 - val_f1_score: 0.5679 - lr: 1.0000e-04
# Epoch 14/60
# 4500/4500 [==============================] - 371s 83ms/step - loss: 1.0926 - accuracy: 0.7077 - precision_1: 0.8387 - recall_1: 0.5934 - f1_score: 0.6917 - val_loss: 1.4062 - val_accuracy: 0.6137 - val_precision_1: 0.7465 - val_recall_1: 0.4613 - val_f1_score: 0.5649 - lr: 1.0000e-04
# Epoch 15/60
# 4500/4500 [==============================] - 369s 82ms/step - loss: 1.0719 - accuracy: 0.7127 - precision_1: 0.8392 - recall_1: 0.6032 - f1_score: 0.6986 - val_loss: 1.4863 - val_accuracy: 0.5955 - val_precision_1: 0.6882 - val_recall_1: 0.5013 - val_f1_score: 0.5764 - lr: 1.0000e-04
# Epoch 16/60
# 4500/4500 [==============================] - 368s 82ms/step - loss: 1.0471 - accuracy: 0.7198 - precision_1: 0.8375 - recall_1: 0.6155 - f1_score: 0.7065 - val_loss: 1.4018 - val_accuracy: 0.6190 - val_precision_1: 0.7290 - val_recall_1: 0.5051 - val_f1_score: 0.5930 - lr: 1.0000e-04
# Epoch 17/60
# 4500/4500 [==============================] - 368s 82ms/step - loss: 1.0306 - accuracy: 0.7261 - precision_1: 0.8434 - recall_1: 0.6242 - f1_score: 0.7145 - val_loss: 1.4650 - val_accuracy: 0.6067 - val_precision_1: 0.6944 - val_recall_1: 0.5126 - val_f1_score: 0.5869 - lr: 1.0000e-04
# Epoch 18/60
# 4500/4500 [==============================] - 365s 81ms/step - loss: 1.0123 - accuracy: 0.7311 - precision_1: 0.8431 - recall_1: 0.6300 - f1_score: 0.7181 - val_loss: 1.3632 - val_accuracy: 0.6303 - val_precision_1: 0.7313 - val_recall_1: 0.5263 - val_f1_score: 0.6085 - lr: 1.0000e-04
# Epoch 19/60
# 4500/4500 [==============================] - 366s 81ms/step - loss: 0.9999 - accuracy: 0.7334 - precision_1: 0.8408 - recall_1: 0.6382 - f1_score: 0.7228 - val_loss: 1.3891 - val_accuracy: 0.6229 - val_precision_1: 0.7237 - val_recall_1: 0.5231 - val_f1_score: 0.6038 - lr: 1.0000e-04
# Epoch 20/60
# 4500/4500 [==============================] - 366s 81ms/step - loss: 0.9853 - accuracy: 0.7388 - precision_1: 0.8450 - recall_1: 0.6453 - f1_score: 0.7290 - val_loss: 1.4174 - val_accuracy: 0.6285 - val_precision_1: 0.7143 - val_recall_1: 0.5335 - val_f1_score: 0.6075 - lr: 1.0000e-04
# Epoch 21/60
# 4500/4500 [==============================] - 406s 90ms/step - loss: 0.9700 - accuracy: 0.7436 - precision_1: 0.8473 - recall_1: 0.6515 - f1_score: 0.7339 - val_loss: 1.3776 - val_accuracy: 0.6279 - val_precision_1: 0.7231 - val_recall_1: 0.5364 - val_f1_score: 0.6131 - lr: 1.0000e-04
# Epoch 22/60
# 4500/4500 [==============================] - 372s 83ms/step - loss: 0.9557 - accuracy: 0.7489 - precision_1: 0.8487 - recall_1: 0.6582 - f1_score: 0.7386 - val_loss: 1.3807 - val_accuracy: 0.6314 - val_precision_1: 0.7342 - val_recall_1: 0.5261 - val_f1_score: 0.6095 - lr: 1.0000e-04
# Epoch 23/60
# 4500/4500 [==============================] - 363s 81ms/step - loss: 0.9497 - accuracy: 0.7519 - precision_1: 0.8494 - recall_1: 0.6621 - f1_score: 0.7414 - val_loss: 1.3102 - val_accuracy: 0.6383 - val_precision_1: 0.7283 - val_recall_1: 0.5376 - val_f1_score: 0.6158 - lr: 1.0000e-04
# Epoch 24/60
# 4500/4500 [==============================] - 367s 82ms/step - loss: 0.9389 - accuracy: 0.7554 - precision_1: 0.8509 - recall_1: 0.6690 - f1_score: 0.7464 - val_loss: 1.3848 - val_accuracy: 0.6213 - val_precision_1: 0.7128 - val_recall_1: 0.5334 - val_f1_score: 0.6070 - lr: 1.0000e-04
# Epoch 25/60
# 4500/4500 [==============================] - 365s 81ms/step - loss: 0.9232 - accuracy: 0.7603 - precision_1: 0.8528 - recall_1: 0.6775 - f1_score: 0.7525 - val_loss: 1.3051 - val_accuracy: 0.6406 - val_precision_1: 0.7234 - val_recall_1: 0.5683 - val_f1_score: 0.6333 - lr: 1.0000e-04
# Epoch 26/60
# 4500/4500 [==============================] - 365s 81ms/step - loss: 0.9121 - accuracy: 0.7642 - precision_1: 0.8527 - recall_1: 0.6829 - f1_score: 0.7560 - val_loss: 1.2922 - val_accuracy: 0.6520 - val_precision_1: 0.7370 - val_recall_1: 0.5718 - val_f1_score: 0.6410 - lr: 1.0000e-04
# Epoch 27/60
# 4500/4500 [==============================] - 367s 81ms/step - loss: 0.9053 - accuracy: 0.7650 - precision_1: 0.8533 - recall_1: 0.6851 - f1_score: 0.7575 - val_loss: 1.3196 - val_accuracy: 0.6352 - val_precision_1: 0.7245 - val_recall_1: 0.5529 - val_f1_score: 0.6248 - lr: 1.0000e-04
# Epoch 28/60
# 4500/4500 [==============================] - 366s 81ms/step - loss: 0.8970 - accuracy: 0.7697 - precision_1: 0.8544 - recall_1: 0.6911 - f1_score: 0.7617 - val_loss: 1.3534 - val_accuracy: 0.6342 - val_precision_1: 0.7135 - val_recall_1: 0.5617 - val_f1_score: 0.6260 - lr: 1.0000e-04
# Epoch 29/60
# 4500/4500 [==============================] - 365s 81ms/step - loss: 0.8921 - accuracy: 0.7722 - precision_1: 0.8546 - recall_1: 0.6960 - f1_score: 0.7647 - val_loss: 1.2969 - val_accuracy: 0.6503 - val_precision_1: 0.7330 - val_recall_1: 0.5718 - val_f1_score: 0.6398 - lr: 1.0000e-04
# Epoch 30/60
# 4500/4500 [==============================] - 365s 81ms/step - loss: 0.8738 - accuracy: 0.7763 - precision_1: 0.8585 - recall_1: 0.7027 - f1_score: 0.7705 - val_loss: 1.2776 - val_accuracy: 0.6543 - val_precision_1: 0.7373 - val_recall_1: 0.5789 - val_f1_score: 0.6463 - lr: 1.0000e-04
# Epoch 31/60
# 4500/4500 [==============================] - 364s 81ms/step - loss: 0.8695 - accuracy: 0.7802 - precision_1: 0.8574 - recall_1: 0.7095 - f1_score: 0.7744 - val_loss: 1.3494 - val_accuracy: 0.6498 - val_precision_1: 0.7161 - val_recall_1: 0.5775 - val_f1_score: 0.6366 - lr: 1.0000e-04
# Epoch 32/60
# 4500/4500 [==============================] - 364s 81ms/step - loss: 0.8634 - accuracy: 0.7825 - precision_1: 0.8581 - recall_1: 0.7117 - f1_score: 0.7759 - val_loss: 1.3834 - val_accuracy: 0.6398 - val_precision_1: 0.7141 - val_recall_1: 0.5643 - val_f1_score: 0.6277 - lr: 1.0000e-04
# Epoch 33/60
# 4500/4500 [==============================] - 366s 81ms/step - loss: 0.8514 - accuracy: 0.7861 - precision_1: 0.8596 - recall_1: 0.7170 - f1_score: 0.7796 - val_loss: 1.4310 - val_accuracy: 0.6310 - val_precision_1: 0.7051 - val_recall_1: 0.5591 - val_f1_score: 0.6208 - lr: 1.0000e-04
# Epoch 34/60
# 4500/4500 [==============================] - 365s 81ms/step - loss: 0.8484 - accuracy: 0.7877 - precision_1: 0.8610 - recall_1: 0.7204 - f1_score: 0.7824 - val_loss: 1.3479 - val_accuracy: 0.6486 - val_precision_1: 0.7239 - val_recall_1: 0.5771 - val_f1_score: 0.6397 - lr: 1.0000e-04
# Epoch 35/60
# 4500/4500 [==============================] - ETA: 0s - loss: 0.8395 - accuracy: 0.7906 - precision_1: 0.8599 - recall_1: 0.7255 - f1_score: 0.7849
# Epoch 35: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 4500/4500 [==============================] - 365s 81ms/step - loss: 0.8395 - accuracy: 0.7906 - precision_1: 0.8599 - recall_1: 0.7255 - f1_score: 0.7849 - val_loss: 1.3066 - val_accuracy: 0.6536 - val_precision_1: 0.7337 - val_recall_1: 0.5802 - val_f1_score: 0.6449 - lr: 1.0000e-04
# Epoch 36/60
# 4500/4500 [==============================] - 365s 81ms/step - loss: 0.7843 - accuracy: 0.8095 - precision_1: 0.8713 - recall_1: 0.7508 - f1_score: 0.8045 - val_loss: 1.3231 - val_accuracy: 0.6576 - val_precision_1: 0.7186 - val_recall_1: 0.5973 - val_f1_score: 0.6496 - lr: 5.0000e-05
# Epoch 37/60
# 4500/4500 [==============================] - ETA: 0s - loss: 0.7590 - accuracy: 0.8164 - precision_1: 0.8743 - recall_1: 0.7636 - f1_score: 0.8135Restoring model weights from the end of the best epoch: 30.
# 4500/4500 [==============================] - 365s 81ms/step - loss: 0.7590 - accuracy: 0.8164 - precision_1: 0.8743 - recall_1: 0.7636 - f1_score: 0.8135 - val_loss: 1.3210 - val_accuracy: 0.6547 - val_precision_1: 0.7157 - val_recall_1: 0.5980 - val_f1_score: 0.6491 - lr: 5.0000e-05
# Epoch 37: early stopping

# %%
val_eval_generator = validation_dataGen.flow_from_directory(
    validation_data,
    color_mode='grayscale', 
    target_size=(48, 48),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Predict on validation data
Y_pred = model.predict(val_eval_generator)
y_pred = np.argmax(Y_pred, axis=1)
y_true = val_eval_generator.classes

# Get class labels
class_names = list(val_eval_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Print classification report
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Found 7628 images belonging to 9 classes.
# 477/477 [==============================] - 15s 31ms/step
#               precision    recall  f1-score   support
#
#        angry       0.52      0.64      0.57       958
#      disgust       0.50      0.72      0.59       111
#         fear       0.56      0.39      0.46      1024
#        happy       0.89      0.82      0.85      1774
#      kissing       0.75      0.69      0.71       290
#      neutral       0.57      0.65      0.61      1233
#          sad       0.51      0.49      0.50      1247
#       sleepy       0.82      1.00      0.90       160
#     surprise       0.75      0.82      0.78       831
#
#     accuracy                           0.65      7628
#    macro avg       0.65      0.69      0.67      7628
# weighted avg       0.66      0.65      0.65      7628
