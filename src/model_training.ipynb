# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.regularizers import l2
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.metrics import Precision, Recall
from focal_loss import BinaryFocalLoss
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
from datetime import datetime
import os
import numpy as np
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm  
import cv2
from sklearn.preprocessing import LabelEncoder

# %%
# Set all random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %%
num_class=7
img_rows,img_cols=48,48 #image size
batch_size=16 #decrease from 32 to 16 back to 32

# %%
# For GPU determinism (if using GPU)
tf.config.experimental.enable_op_determinism()

# %%
# Regularization strength (tunable)
kernel_regularizer = l1_l2(l1=1e-5, l2=1e-4) #new, l1_l2 regularisation

# %%
train_data=r"C:\Users\nourm\OneDrive\Desktop\PROJECTS\UNITY MODEL PROJECT\FER-2013 (USED)-OLD AND REMOVED\train"

validation_data=r"C:\Users\nourm\OneDrive\Desktop\PROJECTS\UNITY MODEL PROJECT\FER-2013 (USED)-OLD AND REMOVED\test"

# %%
# Get the list of folders in the directory as classes
classes=os.listdir(train_data+'/')
classes
# Out:
# ['angry', 'fear', 'happy', 'kissing', 'neutral', 'sad', 'surprise']

# %%
def get_class_distribution(dataset_path):
    class_counts = {folder: len(os.listdir(os.path.join(dataset_path, folder)))
                    for folder in os.listdir(dataset_path)
                    if os.path.isdir(os.path.join(dataset_path, folder))}
    return class_counts

# %%
def plot_class_distribution(class_counts, title="Class Distribution"):
    df = pd.DataFrame(list(class_counts.items()), columns=['Emotion', 'Count'])
    plt.figure(figsize=(10, 6))
    sns.barplot(x='Emotion', y='Count', data=df)
    plt.title(title)
    plt.xlabel('Emotion Class')
    plt.ylabel('Number of Images')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
original_counts = get_class_distribution(train_data)
plot_class_distribution(original_counts, title="Original Class Distribution (Before Oversampling)")

# %%
import os

def rename_photos_in_folder(folder_path):
    if not os.path.exists(folder_path):
        print(f"Folder does not exist: {folder_path}")
        return

    # Get list of files, filter out non-files
    files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
    
    # Sort for consistent renaming order (optional)
    files.sort()

    for i, filename in enumerate(files, start=1):
        ext = os.path.splitext(filename)[1]  # get the file extension (.jpg, .png, etc.)
        new_name = f"img{i}{ext}"
        
        old_path = os.path.join(folder_path, filename)
        new_path = os.path.join(folder_path, new_name)

        os.rename(old_path, new_path)
        print(f"Renamed: {filename} → {new_name}")

# Example usage
rename_photos_in_folder(r"C:\Users\nourm\OneDrive\Desktop\PROJECTS\UNITY MODEL PROJECT\FER-2013 (USED)-OLD AND REMOVED\train\kissing")
# Out:
# Renamed: photo1.jpg → img1.jpg
# Renamed: photo10.jpg → img2.jpg
# Renamed: photo100.jpg → img3.jpg
# Renamed: photo101.jpg → img4.jpg
# Renamed: photo102.jpg → img5.jpg
# Renamed: photo103.jpg → img6.jpg
# Renamed: photo104.jpg → img7.jpg
# Renamed: photo105.jpg → img8.jpg
# Renamed: photo106.jpg → img9.jpg
# Renamed: photo107.jpg → img10.jpg
# Renamed: photo108.jpg → img11.jpg
# Renamed: photo109.jpg → img12.jpg
# Renamed: photo11.jpg → img13.jpg
# Renamed: photo110.jpg → img14.jpg
# Renamed: photo111.jpg → img15.jpg
# Renamed: photo112.jpg → img16.jpg
# Renamed: photo113.jpg → img17.jpg
# Renamed: photo114.jpg → img18.jpg
# Renamed: photo115.jpg → img19.jpg
# Renamed: photo116.jpg → img20.jpg
# Renamed: photo117.jpg → img21.jpg
# Renamed: photo118.jpg → img22.jpg
# Renamed: photo119.jpg → img23.jpg
# Renamed: photo12.jpg → img24.jpg
# Renamed: photo120.jpg → img25.jpg
# Renamed: photo121.jpg → img26.jpg
# Renamed: photo122.jpg → img27.jpg
# Renamed: photo123.jpg → img28.jpg
# Renamed: photo641.jpg → img603.jpg
# Renamed: photo642.jpg → img604.jpg
# Renamed: photo643.jpg → img605.jpg
# Renamed: photo644.jpg → img606.jpg
# Renamed: photo645.jpg → img607.jpg
# Renamed: photo646.jpg → img608.jpg
# Renamed: photo647.jpg → img609.jpg
# Renamed: photo648.jpg → img610.jpg
# Renamed: photo649.jpg → img611.jpg
# Renamed: photo65.jpg → img612.jpg
# Renamed: photo650.jpg → img613.jpg
# Renamed: photo651.jpg → img614.jpg
# Renamed: photo652.jpg → img615.jpg
# Renamed: photo653.jpg → img616.jpg
# Renamed: photo654.jpg → img617.jpg
# Renamed: photo655.jpg → img618.jpg
# Renamed: photo656.jpg → img619.jpg
# Renamed: photo657.jpg → img620.jpg
# Renamed: photo658.jpg → img621.jpg
# Renamed: photo659.jpg → img622.jpg
# Renamed: photo66.jpg → img623.jpg
# Renamed: photo660.jpg → img624.jpg
# Renamed: photo661.jpg → img625.jpg
# Renamed: photo662.jpg → img626.jpg
# Renamed: photo663.jpg → img627.jpg
# Renamed: photo664.jpg → img628.jpg
# Renamed: photo665.jpg → img629.jpg
# Renamed: photo666.jpg → img630.jpg
# Renamed: photo667.jpg → img631.jpg
# Renamed: photo668.jpg → img632.jpg
# Renamed: photo669.jpg → img633.jpg
# Renamed: photo67.jpg → img634.jpg
# Renamed: photo670.jpg → img635.jpg
# Renamed: photo68.jpg → img636.jpg
# Renamed: photo69.jpg → img637.jpg
# Renamed: photo7.jpg → img638.jpg
# Renamed: photo70.jpg → img639.jpg
# Renamed: photo71.jpg → img640.jpg
# Renamed: photo72.jpg → img641.jpg
# Renamed: photo73.jpg → img642.jpg
# Renamed: photo74.jpg → img643.jpg
# Renamed: photo75.jpg → img644.jpg
# Renamed: photo76.jpg → img645.jpg
# Renamed: photo77.jpg → img646.jpg
# Renamed: photo78.jpg → img647.jpg
# Renamed: photo79.jpg → img648.jpg
# Renamed: photo8.jpg → img649.jpg
# Renamed: photo80.jpg → img650.jpg
# Renamed: photo81.jpg → img651.jpg
# Renamed: photo82.jpg → img652.jpg
# Renamed: photo83.jpg → img653.jpg
# Renamed: photo84.jpg → img654.jpg
# Renamed: photo85.jpg → img655.jpg
# Renamed: photo86.jpg → img656.jpg
# Renamed: photo87.jpg → img657.jpg
# Renamed: photo88.jpg → img658.jpg
# Renamed: photo89.jpg → img659.jpg
# Renamed: photo9.jpg → img660.jpg
# Renamed: photo90.jpg → img661.jpg
# Renamed: photo91.jpg → img662.jpg
# Renamed: photo92.jpg → img663.jpg
# Renamed: photo93.jpg → img664.jpg
# Renamed: photo94.jpg → img665.jpg
# Renamed: photo95.jpg → img666.jpg
# Renamed: photo96.jpg → img667.jpg
# Renamed: photo97.jpg → img668.jpg
# Renamed: photo98.jpg → img669.jpg
# Renamed: photo99.jpg → img670.jpg

# %%
import os

def find_file_by_name(root_folder, target_filename):
    """
    Searches for a specific file by name in a folder (recursively).
    
    Args:
        root_folder (str): Path to the folder to search in.
        target_filename (str): The exact file name to search for (e.g., "image1.jpg").
        
    Returns:
        str or None: Full path to the file if found, else None.
    """
    for dirpath, _, filenames in os.walk(root_folder):
        if target_filename in filenames:
            return os.path.join(dirpath, target_filename)
    
    print(f"File '{target_filename}' not found in '{root_folder}'.")
    return None

# Example usage:
path = find_file_by_name(r"C:\Users\nourm\OneDrive\Desktop\PROJECTS\UNITY MODEL PROJECT\FER-2013 (USED)-OLD AND REMOVED\train\kissing", "0_imgi_130_stock-photo-african-american-girl-doing-duck-face-and-taking-selfie-on-smartphone-in-bed-during-morning-time-at-1256411821_face.jpg")
print("Found at:", path)
# Out:
# File '0_imgi_130_stock-photo-african-american-girl-doing-duck-face-and-taking-selfie-on-smartphone-in-bed-during-morning-time-at-1256411821_face.jpg' not found in 'C:\Users\nourm\OneDrive\Desktop\PROJECTS\UNITY MODEL PROJECT\FER-2013 (USED)-OLD AND REMOVED\train\kissing'.
# Found at: None

# %%
OVERSAMPLED_TRAIN_PATH = r'C:\Users\nourm\OneDrive\Desktop\PROJECTS\UNITY MODEL PROJECT\FER-2013 (USED)-OLD AND REMOVED\oversampled_train'
TARGET_LENGTH = 8000  # Set to max class size or any desired balance

def oversample_dataset(train_dir=train_data, oversampled_dir=OVERSAMPLED_TRAIN_PATH, target_length=TARGET_LENGTH):
    if not os.path.exists(oversampled_dir):
        os.makedirs(oversampled_dir)

    for class_name in os.listdir(train_dir):
        class_path = os.path.join(train_dir, class_name)
        if not os.path.isdir(class_path):
            continue

        images = os.listdir(class_path)
        num_images = len(images)
        num_duplicates = target_length // num_images
        remainder = target_length % num_images

        dest_dir = os.path.join(oversampled_dir, class_name)
        os.makedirs(dest_dir, exist_ok=True)

        # Duplicate all images num_duplicates times
        for i in range(num_duplicates):
            for image_name in images:
                src_path = os.path.join(class_path, image_name)
                dst_path = os.path.join(dest_dir, f"{i}_{image_name}")
                Image.open(src_path).save(dst_path)

        # Add remainder images
        for i, image_name in enumerate(images[:remainder]):
            src_path = os.path.join(class_path, image_name)
            dst_path = os.path.join(dest_dir, f"{num_duplicates}_{i}_{image_name}")
            Image.open(src_path).save(dst_path)

oversample_dataset()

# %%
# def smote_augment_multi_folder(input_folder, output_folder, num_augmented_images=1000):
   

#     datagen = ImageDataGenerator(
#         rotation_range=20,
#         width_shift_range=0.1,
#         height_shift_range=0.1,
#         shear_range=0.15,
#         zoom_range=0.1,
#         horizontal_flip=True,
#         fill_mode='nearest'
#     )

#     if not os.path.exists(input_folder):
#         print(f"[ERROR] Input folder does not exist: {input_folder}")
#         return

#     os.makedirs(output_folder, exist_ok=True)

#     for subfolder in os.listdir(input_folder):
#         input_subfolder_path = os.path.join(input_folder, subfolder)
#         output_subfolder_path = os.path.join(output_folder, subfolder)

#         if not os.path.isdir(input_subfolder_path):
#             continue

#         os.makedirs(output_subfolder_path, exist_ok=True)

#         image_files = [f for f in os.listdir(input_subfolder_path)
#                        if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

#         if not image_files:
#             print(f"[WARNING] No images in: {input_subfolder_path}")
#             continue

#         print(f"[INFO] Processing '{subfolder}' - {len(image_files)} images found")

#         count = 0
#         while count < num_augmented_images:
#             img_file = random.choice(image_files)
#             img_path = os.path.join(input_subfolder_path, img_file)

#             try:
#                 img = load_img(img_path)
#                 x = img_to_array(img)
#                 x = x.reshape((1,) + x.shape)

#                 # Generate a batch of 1 augmented image
#                 for batch in datagen.flow(x, batch_size=1):
#                     aug_img = array_to_img(batch[0])

#                     # Generate a unique filename
#                     timestamp = datetime.now().strftime('%Y%m%d%H%M%S%f')
#                     save_name = f"aug_{count}_{timestamp}.png"
#                     save_path = os.path.join(output_subfolder_path, save_name)

#                     aug_img.save(save_path)
#                     count += 1
#                     break

#             except Exception as e:
#                 print(f"[ERROR] Skipping file '{img_file}': {e}")
#                 continue

#         print(f"[DONE] Generated {count} images for '{subfolder}'")

#     print(f"\n[COMPLETE] All folders processed. Output saved to: {output_folder}")

# %%
# SMOTED_OVERSAMPLED_TRAIN_PATH=r"C:\Users\nourm\OneDrive\Desktop\PROJECTS\UNITY MODEL PROJECT\FER-2013 (USED)\SMOTED_OVERSAMPLED"

# smote_augment_multi_folder(
#     input_folder=train_data,
#     output_folder=SMOTED_OVERSAMPLED_TRAIN_PATH,
#     num_augmented_images=7215
# )

# %%
#SMOTED_OVERSAMPLED_TEST=R"C:\Users\nourm\OneDrive\Desktop\PROJECTS\UNITY MODEL PROJECT\FER-2013 (USED)\SMOTED_OVERSAMPLED_TEST"

# smote_augment_multi_folder(
#     input_folder=validation_data,
#     output_folder=SMOTED_OVERSAMPLED_TEST,
#     num_augmented_images=1774
# )

# %%
original_counts = get_class_distribution(OVERSAMPLED_TRAIN_PATH)
plot_class_distribution(original_counts, title="oversampled smote Class Distribution ")

# %%
#image data generator section

#here we generated some images 

train_dataGen=ImageDataGenerator(
    rescale=1./255,
    fill_mode='nearest',
    rotation_range=15,           # Increase from 10 to 15
    shear_range=0.10,            # Increase from 0.1 to 0.2 back to 0.15
    zoom_range=0.10,             # Increase from 0.1 to 0.2 back to 0.15 back to 0.1
    width_shift_range=0.10,      # Increase from 0.1 to 0.2 back to 0.15
    height_shift_range=0.10,     # Increase from 0.1 to 0.2 back to 0.15
    horizontal_flip=True
    #brightness_range=[0.8, 1.2], # ADD: brightness variation- remove for now
    #channel_shift_range=0.1      # ADD: slight channel shift remove for now 
)


validation_dataGen=ImageDataGenerator(rescale=1./255)

#give to model to train-train parameters

train_generator = train_dataGen.flow_from_directory(
  OVERSAMPLED_TRAIN_PATH,
  color_mode='grayscale',
  target_size=(img_rows,img_cols) , 
  batch_size=batch_size,
  class_mode='categorical', 
  shuffle=True
   )

#new - add class weighs

from sklearn.utils.class_weight import compute_class_weight

labels = train_generator.classes  # Numpy array of class indices
class_weights = compute_class_weight(class_weight='balanced',
                                     classes=np.unique(labels),
                                     y=labels)
class_weights_dict = dict(enumerate(class_weights))
print("Class weights:", class_weights_dict)

#end of new

#validation parameters
validation_generator = validation_dataGen.flow_from_directory(validation_data,
color_mode='grayscale',
 target_size=(img_rows,img_cols) , 
 batch_size=batch_size,
   class_mode='categorical', 
   shuffle=True
   )
# Out:
# Found 56000 images belonging to 7 classes.
# Class weights: {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0, 4: 1.0, 5: 1.0, 6: 1.0}
# Found 7247 images belonging to 7 classes.

# %%
model= Sequential()

#change, block 1-4, increase dropout from 0.2 to 0.3 0.2
#change, block 5-6, decrease dropout from 0.5 to 0.4 0.3


# Block 1 - Deeper feature extraction
model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001), input_shape=(img_rows, img_cols, 1)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))


# Block 2 - Increased capacity
model.add(Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))


# Block 3 - Higher-level features
model.add(Conv2D(128, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(128, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(128, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))


# Block 4 - Complex pattern recognition
model.add(Conv2D(256, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(256, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(256, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))


# Block 5 - Additional deep features
model.add(Conv2D(512, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Conv2D(512, (3, 3), padding='same', kernel_initializer='he_normal',
                 kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())

model.add(Dropout(0.4))


# Global Average Pooling - reduces overfitting compared to Flatten
model.add(GlobalAveragePooling2D())


# Fully Connected Dense Layers
model.add(Dense(256, kernel_initializer='he_normal', kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(128, kernel_initializer='he_normal', kernel_regularizer=l2(0.0001)))
model.add(Activation('swish'))
model.add(BatchNormalization())
model.add(Dropout(0.5))


# Output Layer
model.add(Dense(num_class, kernel_initializer='he_normal'))
model.add(Activation('softmax'))


print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_42 (Conv2D)          (None, 48, 48, 32)        320
#
#  activation_51 (Activation)  (None, 48, 48, 32)        0
#
#  batch_normalization_48 (Bat  (None, 48, 48, 32)       128
#  chNormalization)
#
#  conv2d_43 (Conv2D)          (None, 48, 48, 32)        9248
#
#  activation_52 (Activation)  (None, 48, 48, 32)        0
#
#  batch_normalization_49 (Bat  (None, 48, 48, 32)       128
#  chNormalization)
#
#  conv2d_44 (Conv2D)          (None, 48, 48, 32)        9248
#
#  activation_53 (Activation)  (None, 48, 48, 32)        0
#
#  batch_normalization_50 (Bat  (None, 48, 48, 32)       128
#  chNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 24, 24, 32)       0
#  g2D)
#
#  dropout_21 (Dropout)        (None, 24, 24, 32)        0
#
#  conv2d_45 (Conv2D)          (None, 24, 24, 64)        18496
#
#  activation_54 (Activation)  (None, 24, 24, 64)        0
#
#  batch_normalization_51 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  conv2d_46 (Conv2D)          (None, 24, 24, 64)        36928
#
#  activation_55 (Activation)  (None, 24, 24, 64)        0
#
#  batch_normalization_52 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  conv2d_47 (Conv2D)          (None, 24, 24, 64)        36928
#
#  activation_56 (Activation)  (None, 24, 24, 64)        0
#
#  batch_normalization_53 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 12, 12, 64)       0
#  g2D)
#
#  dropout_22 (Dropout)        (None, 12, 12, 64)        0
#
#  conv2d_48 (Conv2D)          (None, 12, 12, 128)       73856
#
#  activation_57 (Activation)  (None, 12, 12, 128)       0
#
#  batch_normalization_54 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  conv2d_49 (Conv2D)          (None, 12, 12, 128)       147584
#
#  activation_58 (Activation)  (None, 12, 12, 128)       0
#
#  batch_normalization_55 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  conv2d_50 (Conv2D)          (None, 12, 12, 128)       147584
#
#  activation_59 (Activation)  (None, 12, 12, 128)       0
#
#  batch_normalization_56 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 6, 6, 128)        0
#  g2D)
#
#  dropout_23 (Dropout)        (None, 6, 6, 128)         0
#
#  conv2d_51 (Conv2D)          (None, 6, 6, 256)         295168
#
#  activation_60 (Activation)  (None, 6, 6, 256)         0
#
#  batch_normalization_57 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv2d_52 (Conv2D)          (None, 6, 6, 256)         590080
#
#  activation_61 (Activation)  (None, 6, 6, 256)         0
#
#  batch_normalization_58 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv2d_53 (Conv2D)          (None, 6, 6, 256)         590080
#
#  activation_62 (Activation)  (None, 6, 6, 256)         0
#
#  batch_normalization_59 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  max_pooling2d_15 (MaxPoolin  (None, 3, 3, 256)        0
#  g2D)
#
#  dropout_24 (Dropout)        (None, 3, 3, 256)         0
#
#  conv2d_54 (Conv2D)          (None, 3, 3, 512)         1180160
#
#  activation_63 (Activation)  (None, 3, 3, 512)         0
#
#  batch_normalization_60 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv2d_55 (Conv2D)          (None, 3, 3, 512)         2359808
#
#  activation_64 (Activation)  (None, 3, 3, 512)         0
#
#  batch_normalization_61 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  dropout_25 (Dropout)        (None, 3, 3, 512)         0
#
#  global_average_pooling2d_3   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_9 (Dense)             (None, 256)               131328
#
#  activation_65 (Activation)  (None, 256)               0
#
#  batch_normalization_62 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_26 (Dropout)        (None, 256)               0
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  activation_66 (Activation)  (None, 128)               0
#
#  batch_normalization_63 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_27 (Dropout)        (None, 128)               0
#
#  dense_11 (Dense)            (None, 7)                 903
#
#  activation_67 (Activation)  (None, 7)                 0
#
# =================================================================
# Total params: 5,672,007
# Trainable params: 5,666,311
# Non-trainable params: 5,696
# _________________________________________________________________
# None

# %%
from keras.optimizers import RMSprop,SGD,Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint = ModelCheckpoint(r'C:\Users\nourm\OneDrive\Desktop\PROJECTS\UNITY MODEL PROJECT\Emotion_little_vgg.h5',
                            monitor='val_loss',
                            mode='min',
                            save_best_only=True,
                            verbose=1)

earlystop = EarlyStopping(monitor='val_loss',
                         min_delta=0,
                         patience=7, #increase from 3
                         verbose=1,
                         restore_best_weights=True
                         )

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                            factor=0.5, #change from 0.2
                            patience=5, #increase from 3
                            verbose=1,
                            min_delta=0.0001)

callbacks = [earlystop,reduce_lr]

optimizer = Adam(learning_rate=0.0001 , clipnorm=1.0)  # Reduced from 0.001

# %%
from tensorflow.keras import backend as K  

def f1_score(y_true, y_pred):
    """Custom F1 score metric"""
    def recall_fn(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision_fn(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    precision_val = precision_fn(y_true, y_pred)
    recall_val = recall_fn(y_true, y_pred)
    return 2*((precision_val*recall_val)/(precision_val+recall_val+K.epsilon()))

# %%
from tensorflow.keras.metrics import Precision, Recall

model.compile(optimizer=optimizer, 
              loss='categorical_crossentropy', 
              metrics=['accuracy', Precision(), Recall(),f1_score]
              )

nb_train_samples = train_generator.samples
nb_validation_samples = validation_generator.samples
epochs=60 #how many times to train same image, model will go 25 times in every folder #increase from 25


history=model.fit(
                train_generator,
                steps_per_epoch=nb_train_samples//batch_size,
                epochs=epochs,
                callbacks=callbacks,
                validation_data=validation_generator,
                validation_steps=nb_validation_samples//batch_size,
                 class_weight=class_weights_dict )

model.save('FER_model.h5')
# Out:
# Epoch 1/60
# 3500/3500 [==============================] - 359s 102ms/step - loss: 2.9001 - accuracy: 0.2282 - precision_3: 0.3149 - recall_3: 0.1111 - f1_score: 0.1635 - val_loss: 2.9478 - val_accuracy: 0.2069 - val_precision_3: 0.1975 - val_recall_3: 0.0615 - val_f1_score: 0.0915 - lr: 1.0000e-04
# Epoch 2/60
# 3500/3500 [==============================] - 287s 82ms/step - loss: 2.3206 - accuracy: 0.3380 - precision_3: 0.6231 - recall_3: 0.1552 - f1_score: 0.2450 - val_loss: 2.8024 - val_accuracy: 0.3001 - val_precision_3: 0.3567 - val_recall_3: 0.1633 - val_f1_score: 0.2205 - lr: 1.0000e-04
# Epoch 3/60
# 3500/3500 [==============================] - 317s 91ms/step - loss: 2.0116 - accuracy: 0.4317 - precision_3: 0.7121 - recall_3: 0.2346 - f1_score: 0.3488 - val_loss: 2.7508 - val_accuracy: 0.3337 - val_precision_3: 0.3878 - val_recall_3: 0.2153 - val_f1_score: 0.2739 - lr: 1.0000e-04
# Epoch 4/60
# 3500/3500 [==============================] - 282s 81ms/step - loss: 1.7988 - accuracy: 0.4956 - precision_3: 0.7454 - recall_3: 0.2959 - f1_score: 0.4202 - val_loss: 2.0087 - val_accuracy: 0.4515 - val_precision_3: 0.5734 - val_recall_3: 0.2944 - val_f1_score: 0.3834 - lr: 1.0000e-04
# Epoch 5/60
# 3500/3500 [==============================] - 289s 83ms/step - loss: 1.6679 - accuracy: 0.5276 - precision_3: 0.7609 - recall_3: 0.3328 - f1_score: 0.4594 - val_loss: 1.8906 - val_accuracy: 0.4736 - val_precision_3: 0.5780 - val_recall_3: 0.3515 - val_f1_score: 0.4337 - lr: 1.0000e-04
# Epoch 6/60
# 3500/3500 [==============================] - 250s 72ms/step - loss: 1.5738 - accuracy: 0.5511 - precision_3: 0.7674 - recall_3: 0.3625 - f1_score: 0.4886 - val_loss: 1.7255 - val_accuracy: 0.5155 - val_precision_3: 0.6466 - val_recall_3: 0.3468 - val_f1_score: 0.4464 - lr: 1.0000e-04
# Epoch 7/60
# 3500/3500 [==============================] - 247s 71ms/step - loss: 1.5010 - accuracy: 0.5695 - precision_3: 0.7657 - recall_3: 0.3885 - f1_score: 0.5118 - val_loss: 1.5244 - val_accuracy: 0.5542 - val_precision_3: 0.7126 - val_recall_3: 0.4011 - val_f1_score: 0.5065 - lr: 1.0000e-04
# Epoch 8/60
# 3500/3500 [==============================] - 246s 70ms/step - loss: 1.4337 - accuracy: 0.5879 - precision_3: 0.7754 - recall_3: 0.4145 - f1_score: 0.5362 - val_loss: 1.5496 - val_accuracy: 0.5635 - val_precision_3: 0.6983 - val_recall_3: 0.4166 - val_f1_score: 0.5169 - lr: 1.0000e-04
# Epoch 9/60
# 3500/3500 [==============================] - 226s 65ms/step - loss: 1.3887 - accuracy: 0.5981 - precision_3: 0.7730 - recall_3: 0.4319 - f1_score: 0.5505 - val_loss: 1.5016 - val_accuracy: 0.5719 - val_precision_3: 0.7293 - val_recall_3: 0.3993 - val_f1_score: 0.5094 - lr: 1.0000e-04
# Epoch 10/60
# 3500/3500 [==============================] - 219s 63ms/step - loss: 1.3561 - accuracy: 0.6049 - precision_3: 0.7749 - recall_3: 0.4397 - f1_score: 0.5570 - val_loss: 1.4432 - val_accuracy: 0.5809 - val_precision_3: 0.6900 - val_recall_3: 0.4663 - val_f1_score: 0.5517 - lr: 1.0000e-04
# Epoch 11/60
# 3500/3500 [==============================] - 215s 61ms/step - loss: 1.3115 - accuracy: 0.6188 - precision_3: 0.7766 - recall_3: 0.4614 - f1_score: 0.5753 - val_loss: 1.4352 - val_accuracy: 0.5855 - val_precision_3: 0.7046 - val_recall_3: 0.4473 - val_f1_score: 0.5427 - lr: 1.0000e-04
# Epoch 12/60
# 3500/3500 [==============================] - 202s 58ms/step - loss: 1.2844 - accuracy: 0.6268 - precision_3: 0.7783 - recall_3: 0.4773 - f1_score: 0.5882 - val_loss: 1.4025 - val_accuracy: 0.5990 - val_precision_3: 0.7211 - val_recall_3: 0.4530 - val_f1_score: 0.5515 - lr: 1.0000e-04
# Epoch 13/60
# 3500/3500 [==============================] - 202s 58ms/step - loss: 1.2595 - accuracy: 0.6310 - precision_3: 0.7796 - recall_3: 0.4851 - f1_score: 0.5944 - val_loss: 1.3508 - val_accuracy: 0.6030 - val_precision_3: 0.7322 - val_recall_3: 0.4779 - val_f1_score: 0.5739 - lr: 1.0000e-04
# Epoch 14/60
# 3500/3500 [==============================] - 195s 56ms/step - loss: 1.2323 - accuracy: 0.6403 - precision_3: 0.7822 - recall_3: 0.4989 - f1_score: 0.6060 - val_loss: 1.4353 - val_accuracy: 0.5918 - val_precision_3: 0.6992 - val_recall_3: 0.4657 - val_f1_score: 0.5554 - lr: 1.0000e-04
# Epoch 15/60
# 3500/3500 [==============================] - 190s 54ms/step - loss: 1.2099 - accuracy: 0.6476 - precision_3: 0.7826 - recall_3: 0.5113 - f1_score: 0.6150 - val_loss: 1.4600 - val_accuracy: 0.5809 - val_precision_3: 0.6950 - val_recall_3: 0.4744 - val_f1_score: 0.5596 - lr: 1.0000e-04
# Epoch 16/60
# 3500/3500 [==============================] - 185s 53ms/step - loss: 1.1909 - accuracy: 0.6514 - precision_3: 0.7844 - recall_3: 0.5166 - f1_score: 0.6196 - val_loss: 1.5364 - val_accuracy: 0.5679 - val_precision_3: 0.6397 - val_recall_3: 0.4752 - val_f1_score: 0.5428 - lr: 1.0000e-04
# Epoch 17/60
# 3500/3500 [==============================] - 185s 53ms/step - loss: 1.1731 - accuracy: 0.6581 - precision_3: 0.7855 - recall_3: 0.5293 - f1_score: 0.6291 - val_loss: 1.2756 - val_accuracy: 0.6300 - val_precision_3: 0.7361 - val_recall_3: 0.5100 - val_f1_score: 0.5987 - lr: 1.0000e-04
# Epoch 18/60
# 3500/3500 [==============================] - 184s 53ms/step - loss: 1.1559 - accuracy: 0.6641 - precision_3: 0.7873 - recall_3: 0.5360 - f1_score: 0.6347 - val_loss: 1.4397 - val_accuracy: 0.6123 - val_precision_3: 0.6955 - val_recall_3: 0.5106 - val_f1_score: 0.5860 - lr: 1.0000e-04
# Epoch 19/60
# 3500/3500 [==============================] - 177s 51ms/step - loss: 1.1433 - accuracy: 0.6657 - precision_3: 0.7915 - recall_3: 0.5421 - f1_score: 0.6403 - val_loss: 1.3505 - val_accuracy: 0.6184 - val_precision_3: 0.7256 - val_recall_3: 0.5059 - val_f1_score: 0.5921 - lr: 1.0000e-04
# Epoch 20/60
# 3500/3500 [==============================] - 175s 50ms/step - loss: 1.1244 - accuracy: 0.6739 - precision_3: 0.7941 - recall_3: 0.5534 - f1_score: 0.6490 - val_loss: 1.2767 - val_accuracy: 0.6314 - val_precision_3: 0.7314 - val_recall_3: 0.5317 - val_f1_score: 0.6116 - lr: 1.0000e-04
# Epoch 21/60
# 3500/3500 [==============================] - 175s 50ms/step - loss: 1.1148 - accuracy: 0.6789 - precision_3: 0.7943 - recall_3: 0.5614 - f1_score: 0.6549 - val_loss: 1.4442 - val_accuracy: 0.6079 - val_precision_3: 0.6939 - val_recall_3: 0.5094 - val_f1_score: 0.5838 - lr: 1.0000e-04
# Epoch 22/60
# 3500/3500 [==============================] - ETA: 0s - loss: 1.0979 - accuracy: 0.6839 - precision_3: 0.7958 - recall_3: 0.5682 - f1_score: 0.6600
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 3500/3500 [==============================] - 175s 50ms/step - loss: 1.0979 - accuracy: 0.6839 - precision_3: 0.7958 - recall_3: 0.5682 - f1_score: 0.6600 - val_loss: 1.3678 - val_accuracy: 0.6242 - val_precision_3: 0.6977 - val_recall_3: 0.5402 - val_f1_score: 0.6067 - lr: 1.0000e-04
# Epoch 23/60
# 3500/3500 [==============================] - 176s 50ms/step - loss: 1.0430 - accuracy: 0.7017 - precision_3: 0.8048 - recall_3: 0.5964 - f1_score: 0.6821 - val_loss: 1.2720 - val_accuracy: 0.6435 - val_precision_3: 0.7296 - val_recall_3: 0.5431 - val_f1_score: 0.6193 - lr: 5.0000e-05
# Epoch 24/60
# 3500/3500 [==============================] - 175s 50ms/step - loss: 1.0254 - accuracy: 0.7061 - precision_3: 0.8060 - recall_3: 0.6052 - f1_score: 0.6886 - val_loss: 1.3439 - val_accuracy: 0.6291 - val_precision_3: 0.7076 - val_recall_3: 0.5451 - val_f1_score: 0.6127 - lr: 5.0000e-05
# Epoch 25/60
# 3500/3500 [==============================] - 178s 51ms/step - loss: 1.0043 - accuracy: 0.7134 - precision_3: 0.8089 - recall_3: 0.6168 - f1_score: 0.6973 - val_loss: 1.2686 - val_accuracy: 0.6406 - val_precision_3: 0.7206 - val_recall_3: 0.5472 - val_f1_score: 0.6189 - lr: 5.0000e-05
# Epoch 26/60
# 3500/3500 [==============================] - 181s 52ms/step - loss: 0.9952 - accuracy: 0.7165 - precision_3: 0.8099 - recall_3: 0.6232 - f1_score: 0.7018 - val_loss: 1.2364 - val_accuracy: 0.6471 - val_precision_3: 0.7300 - val_recall_3: 0.5593 - val_f1_score: 0.6307 - lr: 5.0000e-05
# Epoch 27/60
# 3500/3500 [==============================] - 179s 51ms/step - loss: 0.9843 - accuracy: 0.7209 - precision_3: 0.8111 - recall_3: 0.6285 - f1_score: 0.7057 - val_loss: 1.2841 - val_accuracy: 0.6450 - val_precision_3: 0.7172 - val_recall_3: 0.5729 - val_f1_score: 0.6346 - lr: 5.0000e-05
# Epoch 28/60
# 3500/3500 [==============================] - 182s 52ms/step - loss: 0.9675 - accuracy: 0.7258 - precision_3: 0.8142 - recall_3: 0.6366 - f1_score: 0.7122 - val_loss: 1.2293 - val_accuracy: 0.6527 - val_precision_3: 0.7366 - val_recall_3: 0.5673 - val_f1_score: 0.6383 - lr: 5.0000e-05
# Epoch 29/60
# 3500/3500 [==============================] - 178s 51ms/step - loss: 0.9614 - accuracy: 0.7281 - precision_3: 0.8120 - recall_3: 0.6378 - f1_score: 0.7121 - val_loss: 1.2526 - val_accuracy: 0.6525 - val_precision_3: 0.7330 - val_recall_3: 0.5774 - val_f1_score: 0.6432 - lr: 5.0000e-05
# Epoch 30/60
# 3500/3500 [==============================] - 182s 52ms/step - loss: 0.9469 - accuracy: 0.7343 - precision_3: 0.8148 - recall_3: 0.6490 - f1_score: 0.7201 - val_loss: 1.1997 - val_accuracy: 0.6641 - val_precision_3: 0.7371 - val_recall_3: 0.5931 - val_f1_score: 0.6544 - lr: 5.0000e-05
# Epoch 31/60
# 3500/3500 [==============================] - 201s 57ms/step - loss: 0.9375 - accuracy: 0.7343 - precision_3: 0.8154 - recall_3: 0.6521 - f1_score: 0.7224 - val_loss: 1.3306 - val_accuracy: 0.6386 - val_precision_3: 0.7131 - val_recall_3: 0.5644 - val_f1_score: 0.6273 - lr: 5.0000e-05
# Epoch 32/60
# 3500/3500 [==============================] - 247s 71ms/step - loss: 0.9303 - accuracy: 0.7418 - precision_3: 0.8203 - recall_3: 0.6610 - f1_score: 0.7297 - val_loss: 1.2965 - val_accuracy: 0.6417 - val_precision_3: 0.7093 - val_recall_3: 0.5669 - val_f1_score: 0.6275 - lr: 5.0000e-05
# Epoch 33/60
# 3500/3500 [==============================] - 209s 60ms/step - loss: 0.9148 - accuracy: 0.7420 - precision_3: 0.8221 - recall_3: 0.6649 - f1_score: 0.7331 - val_loss: 1.2370 - val_accuracy: 0.6554 - val_precision_3: 0.7218 - val_recall_3: 0.5861 - val_f1_score: 0.6445 - lr: 5.0000e-05
# Epoch 34/60
# 3500/3500 [==============================] - 180s 51ms/step - loss: 0.9084 - accuracy: 0.7496 - precision_3: 0.8236 - recall_3: 0.6736 - f1_score: 0.7388 - val_loss: 1.2170 - val_accuracy: 0.6604 - val_precision_3: 0.7276 - val_recall_3: 0.5958 - val_f1_score: 0.6532 - lr: 5.0000e-05
# Epoch 35/60
# 3500/3500 [==============================] - ETA: 0s - loss: 0.9033 - accuracy: 0.7493 - precision_3: 0.8234 - recall_3: 0.6759 - f1_score: 0.7403
# Epoch 35: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 3500/3500 [==============================] - 183s 52ms/step - loss: 0.9033 - accuracy: 0.7493 - precision_3: 0.8234 - recall_3: 0.6759 - f1_score: 0.7403 - val_loss: 1.2515 - val_accuracy: 0.6551 - val_precision_3: 0.7217 - val_recall_3: 0.5884 - val_f1_score: 0.6464 - lr: 5.0000e-05
# Epoch 36/60
# 3500/3500 [==============================] - 180s 51ms/step - loss: 0.8670 - accuracy: 0.7632 - precision_3: 0.8323 - recall_3: 0.6948 - f1_score: 0.7554 - val_loss: 1.2493 - val_accuracy: 0.6550 - val_precision_3: 0.7202 - val_recall_3: 0.5906 - val_f1_score: 0.6463 - lr: 2.5000e-05
# Epoch 37/60
# 3500/3500 [==============================] - ETA: 0s - loss: 0.8553 - accuracy: 0.7665 - precision_3: 0.8317 - recall_3: 0.7008 - f1_score: 0.7588Restoring model weights from the end of the best epoch: 30.
# 3500/3500 [==============================] - 184s 52ms/step - loss: 0.8553 - accuracy: 0.7665 - precision_3: 0.8317 - recall_3: 0.7008 - f1_score: 0.7588 - val_loss: 1.2364 - val_accuracy: 0.6550 - val_precision_3: 0.7208 - val_recall_3: 0.5947 - val_f1_score: 0.6498 - lr: 2.5000e-05
# Epoch 37: early stopping

# %%
val_eval_generator = validation_dataGen.flow_from_directory(
    validation_data,
    color_mode='grayscale', 
    target_size=(48, 48),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Predict on validation data
Y_pred = model.predict(val_eval_generator)
y_pred = np.argmax(Y_pred, axis=1)
y_true = val_eval_generator.classes

# Get class labels
class_names = list(val_eval_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Print classification report
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Found 7247 images belonging to 7 classes.
# 453/453 [==============================] - 7s 14ms/step
#               precision    recall  f1-score   support
#
#        angry       0.61      0.63      0.62       958
#         fear       0.65      0.35      0.46      1024
#        happy       0.88      0.84      0.86      1774
#      kissing       0.51      0.56      0.53       180
#      neutral       0.54      0.71      0.62      1233
#          sad       0.55      0.54      0.54      1247
#     surprise       0.74      0.85      0.79       831
#
#     accuracy                           0.66      7247
#    macro avg       0.64      0.64      0.63      7247
# weighted avg       0.67      0.66      0.66      7247
